# %% [markdown]
# # Hierarchical model fit on Splatter datasets

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pystan
import numpy as np
import seaborn as sns
from scipy.stats import norm
import itertools
from sklearn.cluster import KMeans
from sklearn import datasets
import os
import pickle
import scipy
from utils import loadStan, hierarchical_model, est_k
sns.set()
from sklearn.metrics import adjusted_rand_score
import csv
import math
import time

ppca_model = loadStan('ppca')
gmm_model = loadStan('gmm')
moppcas_model = loadStan('moppcas')
moppcas_weighted = loadStan('moppcas_weighted')
ppca_weighted = loadStan('ppca_weighted')
gmm_weighted = loadStan('gmm_weighted')
# Out:
# Loading model  ppca
# Model loaded succesfully from cache.
# Loading model  gmm
# Model loaded succesfully from cache.
# Loading model  moppcas
# Model loaded succesfully from cache.
# Loading model  moppcas_weighted
# Model loaded succesfully from cache.
# Loading model  ppca_weighted
# Model loaded succesfully from cache.
# Loading model  gmm_weighted
# Model loaded succesfully from cache.

# %% [markdown]
# ## Comparison NUTS and VB in terms of speed and accuracy

# %% [markdown]
# ### Dataset 1

# %%
data, labels = pickle.load(open('smallsplat_prep_whole.pkl', 'rb'))
N,D = np.shape(data)
print((N,D))
# Out:
# (500, 400)

# %%
model = hierarchical_model()
latent, cats_per_lvl, probs, times_vb = model.fit(data[:,:15], max_depth=5, k_max=3, samplingmethod='VB', plotting=False)
# timings_vb.append(times_vb)
# Out:
# Loading model  moppcas_weighted
# Model loaded succesfully from cache.
# Loading model  ppca_weighted
# Model loaded succesfully from cache.
# WARNING:pystan:Automatic Differentiation Variational Inference (ADVI) is an EXPERIMENTAL ALGORITHM.
# WARNING:pystan:ADVI samples may be found on the filesystem in the file `/tmp/tmpm9xcrzav/output.csv`
# Estimated number of clusters on top-level data: 3 (out of a maximum of) 3
# level 1:
# Cluster 1:
# First guess: cluster 1 contains 3 subclusters (out of a maximum of 3)
# WARNING:pystan:Automatic Differentiation Variational Inference (ADVI) is an EXPERIMENTAL ALGORITHM.
# WARNING:pystan:ADVI samples may be found on the filesystem in the file `/tmp/tmpl7b9d3e7/output.csv`
# Found MoPPCAs fit with 3 clusters.
# level 2:
# Cluster 1:
# First guess: cluster 1 contains 2 subclusters (out of a maximum of 3)
# WARNING:pystan:Automatic Differentiation Variational Inference (ADVI) is an EXPERIMENTAL ALGORITHM.
# ...

# %%
labelnames = ['gene '+str(i) for i in set(labels)]
scores_vb = model.visual_score(labels, plotlegend=True, savefigs=True, labelnames = labelnames, plot_hmppca = False, plot_hmppca_logres = False, plot_real = True, plot_logreg = True)
# acc_scores_vb.append(scores_vb)
# Out:
# level  0
# level  1
# level  2
# level  3

# %%
timings_nuts = []
timings_vb = []
acc_scores_nuts = []
acc_scores_vb = []
labelnames = ['gene '+str(i+1) for i in set(labels)]

for num_dims in [5,10,25,100]:
    model = hierarchical_model()
    latent, cats_per_lvl, probs, times_vb = model.fit(data[:,:num_dims], max_depth=5, k_max=3, samplingmethod='VB', plotting=False)
    timings_vb.append(times_vb)
    scores_vb = model.visual_score(labels, plotlegend=True, savefigs=True, labelnames = labelnames, plot_hmppca = False, plot_hmppca_logres = False, plot_real = True, plot_logreg = True)
    acc_scores_vb.append(scores_vb)
    
    model = hierarchical_model()
    latent, cats_per_lvl, probs, times_nuts = model.fit(data[:,:num_dims], max_depth=5, k_max=3, samplingmethod='NUTS', plotting=False)
    timings_nuts.append(times_nuts)
    scores_nuts = model.visual_score(labels, plotlegend=True, savefigs=True, labelnames = labelnames, plot_hmppca = False, plot_hmppca_logres = False, plot_real = True, plot_logreg = True)
    acc_scores_nuts.append(scores_nuts)
#     plt.plot(range(1,len(times_vb)+1), times_vb, label='VB')
#     plt.plot(range(1,len(times_nuts)+1), times_nuts, label='NUTS')
#     plt.title('Seconds per (Mo-)PPCAs')
#     plt.ylabel('seconds')
#     plt.legend()
#     plt.show()
    
#     plt.plot(range(len(scores_vb)), scores_vb, label='VB')
#     plt.xlabel('level')
#     plt.ylabel('w. accuracy')
#     plt.plot(range(len(scores_nuts)), scores_nuts, label='NUTS')
#     plt.legend()
#     plt.plot()

# %%
fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(121)
for i in range(4):
    ax.plot(range(len(timings_nuts[i])), timings_nuts[i], label='NUTS, %i dimensions'%[5,10,25,100][i], c= ['red', 'blue', 'green', 'black'][i])
    ax.plot(range(len(timings_vb[i])), timings_vb[i], label='V, %i dimensions'%[5,10,25,100][i], linestyle='--', c= ['red', 'blue', 'green', 'black'][i])
    ax.legend()
    ax.set_ylabel('seconds')
    ax.set_xticks([0,1,2,3,4])
    ax.set_xticklabels(['PPCA', 'MoPPCAs', 'MoPPCAs', 'MoPPCAs', 'MoPPCAs'])
ax = fig.add_subplot(122)
for i in range(4):
    ax.plot(range(len(acc_scores_nuts[i])), acc_scores_nuts[i], label='NUTS, %i dimensions'%[5,10,25,100][i], c= ['red', 'blue', 'green', 'black'][i])
    ax.plot(range(len(acc_scores_vb[i])), acc_scores_vb[i], label='V, %i dimensions'%[5,10,25,100][i], linestyle='--', c= ['red', 'blue', 'green', 'black'][i])
    ax.legend()
    ax.set_ylabel('accuracy')
    ax.set_xticks([0,1,2,3,4])
    ax.set_xticklabels(['PPCA', 'MoPPCAs', 'MoPPCAs', 'MoPPCAs', 'MoPPCAs'])
plt.show()

# %% [markdown]
# ### Dataset 2

# %%
data2, labels2 = pickle.load(open('bigsplat_prep.pkl', 'rb'))
N,D = np.shape(data2)
print((N,D))
# Out:
# (600, 400)

# %%
timings_nuts2 = []
timings_vb2 = []
acc_scores_nuts2 = []
acc_scores_vb2 = []
labelnames = ['gene '+str(i+1) for i in set(labels2)]

for num_dims in [5,10,25,100]:
    model = hierarchical_model()
    latent, cats_per_lvl, probs, times_vb = model.fit(data2[:,:num_dims], max_depth=5, k_max=3, samplingmethod='VB', plotting=False)
    timings_vb2.append(times_vb)
    scores_vb = model.visual_score(labels2, plotlegend=True, savefigs=True, labelnames = labelnames, plot_hmppca = False, plot_hmppca_logres = False, plot_real = True, plot_logreg = True)
    acc_scores_vb2.append(scores_vb)
    
    model = hierarchical_model()
    latent, cats_per_lvl, probs, times_nuts = model.fit(data2[:,:num_dims], max_depth=5, k_max=3, samplingmethod='NUTS', plotting=False)
    timings_nuts2.append(times_nuts)
    scores_nuts = model.visual_score(labels2, plotlegend=True, savefigs=True, labelnames = labelnames, plot_hmppca = False, plot_hmppca_logres = False, plot_real = True, plot_logreg = True)
    acc_scores_nuts2.append(scores_nuts)
#     plt.plot(range(1,len(times_vb)+1), times_vb, label='VB')
#     plt.plot(range(1,len(times_nuts)+1), times_nuts, label='NUTS')
#     plt.title('Seconds per (Mo-)PPCAs')
#     plt.ylabel('seconds')
#     plt.legend()
#     plt.show()
    
#     plt.plot(range(len(scores_vb)), scores_vb, label='VB')
#     plt.xlabel('level')
#     plt.ylabel('w. accuracy')
#     plt.plot(range(len(scores_nuts)), scores_nuts, label='NUTS')
#     plt.legend()
#     plt.plot()

# %%
fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(121)
for i in range(4):
    ax.plot(range(len(timings_nuts2[i])), timings_nuts2[i], label='NUTS, %i dimensions'%[5,10,25,100][i], c= ['red', 'blue', 'green', 'black'][i])
    ax.plot(range(len(timings_vb2[i])), timings_vb2[i], label='V, %i dimensions'%[5,10,25,100][i], linestyle='--', c= ['red', 'blue', 'green', 'black'][i])
    ax.legend()
    ax.set_ylabel('seconds')
    ax.set_xticks([0,1,2,3,4])
    ax.set_xticklabels(['PPCA', 'MoPPCAs', 'MoPPCAs', 'MoPPCAs', 'MoPPCAs'])
ax = fig.add_subplot(122)
for i in range(4):
    ax.plot(range(len(acc_scores_nuts2[i])), acc_scores_nuts2[i], label='NUTS, %i dimensions'%[5,10,25,100][i], c= ['red', 'blue', 'green', 'black'][i])
    ax.plot(range(len(acc_scores_vb2[i])), acc_scores_vb2[i], label='VB, %i dimensions'%[5,10,25,100][i], linestyle='--', c= ['red', 'blue', 'green', 'black'][i])
    ax.legend()
    ax.set_ylabel('accuracy')
    ax.set_xticks([0,1,2,3,4])
    ax.set_xticklabels(['PPCA', 'MoPPCAs', 'MoPPCAs', 'MoPPCAs', 'MoPPCAs'])
plt.show()

# %%
acc_scores_nuts2
# Out:
# [[0.3333333333333333, 0.32955810496607907, 0.37238883378478704],
#  [0.4533333333333333,
#   0.24438130783834872,
#   0.4578262609192982,
#   0.4655100921223814,
#   0.19693477296013123,
#   0.20242307119340444],
#  [0.06166666666666667, 0.2947155215445694, 0.31787643355983786]]

# %%
timings_nuts2
# Out:
# [[36.2119357585907, 83.75945949554443],
#  [61.421977519989014,
#   123.1520607471466,
#   1234.095534324646,
#   1057.7465844154358,
#   1034.5811131000519,
#   913.829532623291],
#  [106.75782179832458, 192.73783469200134]]

# %%
labelnames = ['gene '+str(i+1) for i in set(labels)]

# %%
model.visual_score(labels, plotlegend=True, savefigs=True, labelnames = labelnames)
# Out:
# level  0
# level  1
# level  2
# level  3

# %% [markdown]
# ## Splatter 1 (small and simple)

# %% [markdown]
# ## Loading data

# %%
with open('../Splatter/smallsplat.csv') as file:
    text = csv.reader(file)
    data = np.array(np.array(list(text))[1:,1:].T, dtype=int)
with open('../Splatter/smallsplat_labels.csv') as file:
    text = csv.reader(file)
    labels_raw = np.array(list(text))
    labels = np.unique(labels_raw[1:,1], return_inverse=True)[1]

# %%
print(data[:6,:6])
print(labels[:6])
# Out:
# [[ 38   0   3   4  24   2]
#  [  8   4   0  17  12   2]
#  [ 34   0   2  14  52   2]
#  [ 22   0   0  20  43   0]
#  [ 25   0   3   8  20   5]
#  [ 58   1   8   1 100  15]]
# [3 3 0 0 3 1]

# %%
ct, ct_count = np.unique(labels, return_counts=True)
for i,j in zip(ct, ct_count):
    print(i,'\t',j)
# Out:
# 0 	 95
# 1 	 116
# 2 	 88
# 3 	 98
# 4 	 103

# %% [markdown]
# ### Loading/Saving  formatted data

# %%
# with open('splat_small.pkl', 'wb') as f:
#     pickle.dump([data, labels], f)

# %%
data, labels = pickle.load(open('splat_small.pkl', 'rb'))
N,D = np.shape(data)
print((N,D))
# Out:
# (500, 400)

# %% [markdown]
# ## Pre-analysis

# %% [markdown]
# ### Some explames of distributions of genes

# %%
plotdata = [np.concatenate(data[labels==i,:]) for i in range(len(set(labels)))]

sns.set()
plt.violinplot(plotdata, range(len(set(labels))), points=20, widths=0.3,showmeans=True, showextrema=True, showmedians=True)
plt.show()

# %%
genes = np.random.choice(list(range(D)), p= np.std(data,axis=0)/sum(np.std(data,axis=0)), size=10, replace=False)
for i in range(3):
    plt.hist(data[:,genes[i]], bins=100)
    plt.show()

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Transform data

# %%
data = np.log2(data+1)

# %%
order = np.argsort(-np.std(data, axis=0))
data = data[:,order]

# %%
plotdata = [np.concatenate(data[labels==i,:]) for i in range(len(set(labels)))]
sns.set()
plt.violinplot(plotdata, range(len(set(labels))), points=20, widths=0.3,showmeans=True, showextrema=True, showmedians=True)
plt.show()

# %%
# with open('smallsplat_prep_whole.pkl', 'wb') as f:
#     pickle.dump([data, labels], f)

# %%
data, labels = pickle.load(open('smallsplat_prep_whole.pkl', 'rb'))
N,D = np.shape(data)
print((N,D))
# Out:
# (500, 400)

# %% [markdown]
# ### Number of clusters is estimated fairly high

# %%
K, _ = est_k(data, k_max = 25, verbose=False, method='bic', refs=3)
print('Estimated number of clusters: ',K)
# Out:
# Estimated number of clusters:  19

# %% [markdown]
# ### Clear classes can be observed

# %%
n_test = 5
labels_test = KMeans(n_test).fit(data).labels_

# %%
res = np.zeros((5,n_test))
for r in range(5):
    for t in range(n_test):
        res[r,t] = sum(labels[labels_test==t]==r)
    res[r,:] = res[r,:]/sum(res[r,:])
sns.set()
plt.imshow(res, label='Percentage samples')
plt.colorbar()
plt.ylabel('True')
plt.xlabel('Predicted')
plt.show()

# %%
adjusted_rand_score(labels, labels_test)
# Out:
# 1.0

# %% [markdown]
# ## Analysis

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pystan
import numpy as np
import seaborn as sns
from scipy.stats import norm
import itertools
from sklearn.cluster import KMeans
from sklearn import datasets
import os
import pickle
import scipy
from utils import loadStan, hierarchical_model, est_k
sns.set()
from sklearn.metrics import adjusted_rand_score
import csv
import math
import time

ppca_model = loadStan('ppca')
gmm_model = loadStan('gmm')
moppcas_model = loadStan('moppcas')
moppcas_weighted = loadStan('moppcas_weighted')
ppca_weighted = loadStan('ppca_weighted')
gmm_weighted = loadStan('gmm_weighted')
# Out:
# Loading model  ppca
# Model loaded succesfully from cache.
# Loading model  gmm
# Model loaded succesfully from cache.
# Loading model  moppcas
# Model loaded succesfully from cache.
# Loading model  moppcas_weighted
# Model loaded succesfully from cache.
# Loading model  ppca_weighted
# Model loaded succesfully from cache.
# Loading model  gmm_weighted
# Model loaded succesfully from cache.

# %%
data, labels = pickle.load(open('smallsplat_prep_whole.pkl', 'rb'))
N,D = np.shape(data)
print((N,D))
# Out:
# (500, 400)

# %%
model = hierarchical_model()
latent, cats_per_lvl, probs = model.fit(data[:,:25], max_depth=5, k_max=3, samplingmethod='NUTS')

# %%
model.visual_score(labels)
# Out:
# level  0
# level  1
# level  2
# level  3

# %% [markdown]
# ## Splatter 2 (Larger and more complex)

# %% [markdown]
# ## Loading data

# %%
with open('../Splatter/bigsplat.csv') as file:
    text = csv.reader(file)
    data = np.array(np.array(list(text))[1:,1:].T, dtype=int)
with open('../Splatter/bigsplat_labels.csv') as file:
    text = csv.reader(file)
    labels_raw = np.array(list(text))
    labels = np.unique(labels_raw[1:,1], return_inverse=True)[1]

# %%
print(data[:6,:6])
print(labels[:6])
# Out:
# [[152  14  30  64   2 256]
#  [ 88   6  12  46   0 198]
#  [165  28  21  94   8 404]
#  [129  32  39  54   1 364]
#  [107  17  22  38   4 302]
#  [104  23  22  44   3 229]]
# [5 2 5 4 4 4]

# %%
ct, ct_count = np.unique(labels, return_counts=True)
for i,j in zip(ct, ct_count):
    print(i,'\t',j)
# Out:
# 0 	 126
# 1 	 59
# 2 	 49
# 3 	 11
# 4 	 245
# 5 	 110

# %% [markdown]
# ### Loading/Saving  formatted data

# %%
# with open('big_splat.pkl', 'wb') as f:
#     pickle.dump([data, labels], f)

# %%
data, labels = pickle.load(open('big_splat.pkl', 'rb'))
N,D = np.shape(data)
print((N,D))
# Out:
# (600, 400)

# %% [markdown]
# ## Pre-analysis

# %% [markdown]
# ### Some explames of distributions of genes

# %%
plotdata = [np.concatenate(data[labels==i,:]) for i in range(len(set(labels)))]

sns.set()
plt.violinplot(plotdata, range(len(set(labels))), points=20, widths=0.3,showmeans=True, showextrema=True, showmedians=True)
plt.show()

# %%
genes = np.random.choice(list(range(D)), p= np.std(data,axis=0)/sum(np.std(data,axis=0)), size=10, replace=False)
for i in range(10):
    plt.hist(data[:,genes[i]], bins=20)
    plt.show()

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Transform data

# %%
data = np.log2(data+1)

# %%
plotdata = [np.concatenate(trans_data[labels==i,:]) for i in range(len(set(labels)))]
sns.set()
plt.violinplot(plotdata, range(len(set(labels))), points=20, widths=0.3,showmeans=True, showextrema=True, showmedians=True)
plt.show()

# %% [markdown]
# ### Loading/Saving  preprocessed data

# %%
# with open('bigsplat_prep.pkl', 'wb') as f:
#     pickle.dump([data, labels], f)

# %%
data, labels = pickle.load(open('bigsplat_prep.pkl', 'rb'))
N,D = np.shape(data)
print((N,D))
# Out:
# (600, 400)

# %% [markdown]
# ### Number of clusters is estimated fairly high

# %%
K, _ = est_k(data, k_max = 25, verbose=False, method='bic', refs=3)
print('Estimated number of clusters: ',K)
# Out:
# Estimated number of clusters:  15

# %% [markdown]
# ### Some classes can be observed

# %%
n_test = 6
labels_test = KMeans(n_test).fit(data).labels_

# %%
res = np.zeros((5,n_test))
for r in range(5):
    for t in range(n_test):
        res[r,t] = sum(labels[labels_test==t]==r)
    res[r,:] = res[r,:]/sum(res[r,:])
sns.set()
plt.imshow(res, label='Percentage samples')
plt.colorbar()
plt.ylabel('True')
plt.xlabel('Predicted')
plt.show()

# %%
adjusted_rand_score(labels, labels_test)
# Out:
# 0.483979716499772

# %% [markdown]
# ## Analysis

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pystan
import numpy as np
import seaborn as sns
from scipy.stats import norm
import itertools
from sklearn.cluster import KMeans
from sklearn import datasets
import os
import pickle
import scipy
from utils import loadStan, hierarchical_model, est_k
sns.set()
from sklearn.metrics import adjusted_rand_score
import csv
import math
import time

ppca_model = loadStan('ppca')
gmm_model = loadStan('gmm')
moppcas_model = loadStan('moppcas')
moppcas_weighted = loadStan('moppcas_weighted')
ppca_weighted = loadStan('ppca_weighted')
gmm_weighted = loadStan('gmm_weighted')
# Out:
# Loading model  ppca
# Model loaded succesfully from cache.
# Loading model  gmm
# Model loaded succesfully from cache.
# Loading model  moppcas
# Model loaded succesfully from cache.
# Loading model  moppcas_weighted
# Model loaded succesfully from cache.
# Loading model  ppca_weighted
# Model loaded succesfully from cache.
# Loading model  gmm_weighted
# Model loaded succesfully from cache.

# %%
data2, labels2 = pickle.load(open('bigsplat_prep.pkl', 'rb'))
N,D = np.shape(data2)
print((N,D))
# Out:
# (600, 400)

# %%
model2 = hierarchical_model()
latent2, cats_per_lvl2, probs2 = model2.fit(data2)
# Out:
# Loading model  moppcas_weighted
# Model loaded succesfully from cache.
# Loading model  ppca_weighted
# Model loaded succesfully from cache.
# Latent data on top level:
# WARNING:pystan:Automatic Differentiation Variational Inference (ADVI) is an EXPERIMENTAL ALGORITHM.
# WARNING:pystan:ADVI samples may be found on the filesystem in the file `/tmp/tmp6fxkaoou/output.csv`
# Estimated number of clusters on top-level data: 2 (out of a maximum of) 3
# level 1:
# Cluster 1:
# First guess: cluster 1 contains 2 subclusters (out of a maximum of 3)
# WARNING:pystan:Automatic Differentiation Variational Inference (ADVI) is an EXPERIMENTAL ALGORITHM.
# WARNING:pystan:ADVI samples may be found on the filesystem in the file `/tmp/tmpamc_nxaw/output.csv`
# Found MoPPCAs fit with 1 clusters.
# Trying again for a better fit.
# WARNING:pystan:Automatic Differentiation Variational Inference (ADVI) is an EXPERIMENTAL ALGORITHM.
# ...

# %%
model2.visual_score(labels2)
# Out:
# level  0
# level  1
