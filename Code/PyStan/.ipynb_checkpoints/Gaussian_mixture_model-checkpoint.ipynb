# %% [markdown]
# # Gaussian Mixture Model
#
# In this notebook, we try a parameter estimation for a Gaussian mixture model in Pystan. The model is based upon the [Stan users guide](https://mc-stan.org/docs/2_18/stan-users-guide/summing-out-the-responsibility-parameter.html). A workaround has been implemented because Stan is not able to work with discrete parameters, as explained in the users guide.

# %%
from mpl_toolkits.mplot3d import Axes3D
import pystan
import numpy as np
import seaborn as sns
from sklearn import datasets
from scipy.stats import norm, multivariate_normal
from sklearn.cluster import KMeans
import pickle
from utils import loadStan
sns.set()

# %% [markdown]
# Here, the model is defined in Stan.

# %%
gmm = loadStan('gmm')
# Out:
# Model loaded succesfully from cache.

# %% [markdown]
# We specify our parameters and generate some data.

# %%
N=1000
K=4
D=3
y_gmm = []
z_gmm = []
mu = np.random.uniform(-30,30,size=(K,D))
# sigmas = [np.random.uniform(0,5, size=D) for i in range(K)]
# covariance = [np.diag(sigmas[k]) for k in range(K)]

sigmas = [3*datasets.make_spd_matrix(D) for i in range(K)]

while True:      # make sure to not have a negligible cluster
    theta = np.random.dirichlet(np.ones(K))
    if np.all(theta>(1.0/(2*K))):
        break
        
for i in range(N):
    opt = np.random.choice(list(range(K)),p=theta)
    z_gmm.append(opt)
    y_gmm.append(np.random.multivariate_normal(mu[opt],sigmas[opt]))
y_gmm = np.array(y_gmm)

sns.set()

fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')
ax.scatter(y_gmm[:,0], y_gmm[:,1], y_gmm[:,2], c=z_gmm, cmap='viridis', alpha=0.3)
plt.show()

sample_theta = []
sample_sigma = []
sample_mu = []

for k in range(K):
    sample_theta.append(len(y_gmm[np.array(z_gmm)==k])/N)
    sample_mu.append(list(np.mean(y_gmm[np.array(z_gmm)==k], axis=0)))
    sample_sigma.append(np.cov(y_gmm[np.array(z_gmm)==k].T))

print('sample theta: ', sample_theta)
print()
for k in range(K):
    print('real mu_'+str(k)+': ', mu[k])
    print('sample mu_'+str(k)+': ', sample_mu[k])
    print('real sigmas_'+str(k)+':\n', sigmas[k])
    print('sample covariance_'+str(k)+':\n', sample_sigma[k])
    print()
# Out:
# sample theta:  [0.177, 0.243, 0.289, 0.291]
#
# real mu_0:  [-15.61830697 -16.44092248 -26.37528114]
# sample mu_0:  [-15.68154286412413, -16.320037241844407, -26.626845697959293]
# real sigmas_0:
#  [[ 1.81692541  0.45693532 -0.89350988]
#  [ 0.45693532  1.70649094  1.060953  ]
#  [-0.89350988  1.060953   10.58271187]]
# sample covariance_0:
#  [[ 2.24212969  0.44411482 -1.36119975]
#  [ 0.44411482  1.66640987  1.65273307]
#  [-1.36119975  1.65273307  9.61737106]]
#
# real mu_1:  [ -6.45258872 -16.5282069   -3.462816  ]
# sample mu_1:  [-6.41185126929116, -16.577101507800666, -3.3137958184633645]
# real sigmas_1:
#  [[ 1.73086657  0.71576295  0.72726735]
#  [ 0.71576295  1.73543435  2.01583595]
#  [ 0.72726735  2.01583595 10.01549011]]
# sample covariance_1:
#  [[1.66949718 0.72591966 0.65021332]
#  [0.72591966 1.60456637 1.82654166]
#  [0.65021332 1.82654166 8.74186547]]
#
# real mu_2:  [-18.01328969 -23.77646566  10.04729619]
# sample mu_2:  [-17.985936791629666, -23.7634546682586, 9.994597968955944]
# real sigmas_2:
#  [[ 8.62877925  2.99629393 -0.80714343]
#  [ 2.99629393  2.00454038 -0.68866968]
#  [-0.80714343 -0.68866968  0.97201812]]
# sample covariance_2:
#  [[ 7.52688024  2.59061958 -0.8903348 ]
#  [ 2.59061958  1.9382296  -0.8003588 ]
#  [-0.8903348  -0.8003588   1.05208323]]
#
# real mu_3:  [ 10.6964974  -16.55931382  -6.32861223]
# sample mu_3:  [10.759958057125843, -16.54322078666812, -6.171484300883728]
# real sigmas_3:
#  [[ 1.9232441   1.58834848 -0.51561276]
#  [ 1.58834848 10.38270398  0.06005804]
#  [-0.51561276  0.06005804  1.53186959]]
# sample covariance_3:
#  [[ 1.96590563  1.92706119 -0.4462036 ]
#  [ 1.92706119  9.7339333  -0.16534565]
#  [-0.4462036  -0.16534565  1.3787651 ]]

# %% [markdown]
# And then we can optimize our parameters and latent dataset. Since the optimalization is highly dependend on the initial values, we initialize $\mu$ with the simple result of a $k$-means clustering algorithm.

# %%
kmeans_init = KMeans(K).fit(y_gmm)

gmm_dat = {'N': N,'K': K, 'D':D, 'y':y_gmm}
fit = gmm.sampling(data=gmm_dat, chains=1, iter=150, init=[{'mu':kmeans_init.cluster_centers_}])
fit_ext = fit.extract()
best_ind = np.where(fit_ext['lp__']==max(fit_ext['lp__']))[0][0]
# Out:
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)

# %%
kmeans_init = KMeans(K).fit(y_gmm)

gmm_dat = {'N': N,'K': K, 'D':D, 'y':y_gmm}
fit = gmm.sampling(data=gmm_dat, chains=1, iter=150, init=[{'mu':kmeans_init.cluster_centers_}])
fit_ext = fit.extract()
best_ind = np.where(fit_ext['lp__']==max(fit_ext['lp__']))[0][0]

z_sim = np.mean(fit_ext['z'],axis=0)
theta_sim = np.mean(fit_ext['theta'],axis=0)
mu_sim = np.mean(fit_ext['mu'],axis=0)
sigmas_sim = np.mean(fit_ext['sigma'],axis=0)
# cov_sim = np.mean(fit_ext['covariance'],axis=0)

# z_sim = fit_ext['z'][best_ind]
# theta_sim = fit_ext['theta'][best_ind]
# mu_sim = fit_ext['mu'][best_ind]
# sigmas_sim = fit_ext['sigma'][best_ind]
# cov_sim = fit_ext['covariance'][best_ind]


print('Real theta: ',theta)
print('Sample theta: ',sample_theta)
print('Simulated theta: ',theta_sim)
print()
print('Real mu:\n',mu)
print('Sample mu:\n',np.array(sample_mu))
print('Simulated mu:\n',mu_sim)
print()
print('Real sigmas:')
for i in range(K):
    print(sigmas[i], '\n')
print('Sample cov. matrices:\n',np.array(sample_sigma))
# print('Simulated cov. matrices:\n',cov_sim)
# Out:
# Real theta:  [0.182689   0.24576318 0.28323881 0.288309  ]
# Sample theta:  [0.177, 0.243, 0.289, 0.291]
# Simulated theta:  [0.286937   0.29228672 0.17603268 0.2447436 ]
#
# Real mu:
#  [[-15.61830697 -16.44092248 -26.37528114]
#  [ -6.45258872 -16.5282069   -3.462816  ]
#  [-18.01328969 -23.77646566  10.04729619]
#  [ 10.6964974  -16.55931382  -6.32861223]]
# Sample mu:
#  [[-15.68154286 -16.32003724 -26.6268457 ]
#  [ -6.41185127 -16.57710151  -3.31379582]
#  [-17.98593679 -23.76345467   9.99459797]
#  [ 10.75995806 -16.54322079  -6.1714843 ]]
# Simulated mu:
#  [[-17.98615207 -23.76529668   9.99862023]
#  [ 10.74959637 -16.56880541  -6.16517731]
#  [-15.67933404 -16.31547536 -26.64044688]
#  [ -6.4015004  -16.5606322   -3.27552038]]
#
# Real sigmas:
# [[ 1.81692541  0.45693532 -0.89350988]
#  [ 0.45693532  1.70649094  1.060953  ]
#  [-0.89350988  1.060953   10.58271187]]
#
# [[ 1.73086657  0.71576295  0.72726735]
#  [ 0.71576295  1.73543435  2.01583595]
#  [ 0.72726735  2.01583595 10.01549011]]
#
# [[ 8.62877925  2.99629393 -0.80714343]
#  [ 2.99629393  2.00454038 -0.68866968]
#  [-0.80714343 -0.68866968  0.97201812]]
#
# [[ 1.9232441   1.58834848 -0.51561276]
#  [ 1.58834848 10.38270398  0.06005804]
#  [-0.51561276  0.06005804  1.53186959]]
#
# Sample cov. matrices:
#  [[[ 2.24212969  0.44411482 -1.36119975]
#   [ 0.44411482  1.66640987  1.65273307]
#   [-1.36119975  1.65273307  9.61737106]]
#
#  [[ 1.66949718  0.72591966  0.65021332]
#   [ 0.72591966  1.60456637  1.82654166]
#   [ 0.65021332  1.82654166  8.74186547]]
#
#  [[ 7.52688024  2.59061958 -0.8903348 ]
#   [ 2.59061958  1.9382296  -0.8003588 ]
#   [-0.8903348  -0.8003588   1.05208323]]
#
#  [[ 1.96590563  1.92706119 -0.4462036 ]
#   [ 1.92706119  9.7339333  -0.16534565]
#   [-0.4462036  -0.16534565  1.3787651 ]]]

# %%
z_sim_norm = (np.exp(z_sim).T/sum(np.exp(z_sim).T)).T

# %%
# # # debug check for mixture components analysis
# z_sim = np.zeros((N,K))
# for n in range (N):
#     for k in range(K):
#         z_sim[n,k] += np.log(theta_sim[k])
#         z_sim[n,k] += multivariate_normal.logpdf(y_gmm[n,:], mu_sim[k], cov_sim[k])

# %%
z_cats = []
for n in range(N):
    for k in range(K):
        if z_sim[n,k] == max(z_sim[n]):
            z_cats.append(k)
            break

# %%
z_sim_norm = (np.exp(z_sim).T/sum(np.exp(z_sim).T)).T

z_cats = np.argmax(z_sim_norm, axis=1)

z_sim_rec, y_sim = [], []
for i in range(N):
    opt = np.random.choice(list(range(K)),p=theta_sim)
    z_sim_rec.append(opt)
    y_sim.append(np.random.multivariate_normal(mu_sim[opt],cov_sim[opt]))

y_sim = np.array(y_sim)    
    
fig = plt.figure(figsize=(15,10))

ax = fig.add_subplot(2,2,1, projection='3d')
ax.scatter(np.array(y_gmm)[:,0], np.array(y_gmm)[:,1], np.array(y_gmm)[:,2], c=z_gmm, cmap='viridis', alpha=0.6)
ax.set_xlim(min(np.min(y_gmm[:,0]),np.min(y_sim[:,0]))-5,max(np.max(y_gmm[:,0]),np.max(y_sim[:,0]))+5)
ax.set_ylim(min(np.min(y_gmm[:,1]),np.min(y_sim[:,1]))-5,max(np.max(y_gmm[:,1]),np.max(y_sim[:,1]))+5)
ax.set_zlim(min(np.min(y_gmm[:,2]),np.min(y_sim[:,2]))-5,max(np.max(y_gmm[:,2]),np.max(y_sim[:,2]))+5)
title = ax.set_title("Original sample")
plt.setp(title, color='black') 

ax = fig.add_subplot(2,2,2, projection='3d')
ax.scatter(np.array(y_gmm)[:,0], np.array(y_gmm)[:,1], np.array(y_gmm)[:,2], cmap='viridis')
ax.set_xlim(min(np.min(y_gmm[:,0]),np.min(y_sim[:,0]))-5,max(np.max(y_gmm[:,0]),np.max(y_sim[:,0]))+5)
ax.set_ylim(min(np.min(y_gmm[:,1]),np.min(y_sim[:,1]))-5,max(np.max(y_gmm[:,1]),np.max(y_sim[:,1]))+5)
ax.set_zlim(min(np.min(y_gmm[:,2]),np.min(y_sim[:,2]))-5,max(np.max(y_gmm[:,2]),np.max(y_sim[:,2]))+5)
title = ax.set_title("Unlabeled sample")
plt.setp(title, color='black') 

ax = fig.add_subplot(2,2,3, projection='3d')
ax.scatter(np.array(y_gmm)[:,0], np.array(y_gmm)[:,1], np.array(y_gmm)[:,2], c=z_cats, cmap='viridis', alpha=0.6)
ax.scatter(mu_sim[:,0], mu_sim[:,1], mu_sim[:,2], c='red')
ax.set_xlim(min(np.min(y_gmm[:,0]),np.min(y_sim[:,0]))-5,max(np.max(y_gmm[:,0]),np.max(y_sim[:,0]))+5)
ax.set_ylim(min(np.min(y_gmm[:,1]),np.min(y_sim[:,1]))-5,max(np.max(y_gmm[:,1]),np.max(y_sim[:,1]))+5)
ax.set_zlim(min(np.min(y_gmm[:,2]),np.min(y_sim[:,2]))-5,max(np.max(y_gmm[:,2]),np.max(y_sim[:,2]))+5)
title = ax.set_title("Guessed clusters")
plt.setp(title, color='black') 

ax = fig.add_subplot(2,2,4, projection='3d')
ax.scatter(np.array(y_sim)[:,0], np.array(y_sim)[:,1], np.array(y_sim)[:,2], c=z_sim_rec, cmap='viridis', alpha=0.6)
ax.set_xlim(min(np.min(y_gmm[:,0]),np.min(y_sim[:,0]))-5,max(np.max(y_gmm[:,0]),np.max(y_sim[:,0]))+5)
ax.set_ylim(min(np.min(y_gmm[:,1]),np.min(y_sim[:,1]))-5,max(np.max(y_gmm[:,1]),np.max(y_sim[:,1]))+5)
ax.set_zlim(min(np.min(y_gmm[:,2]),np.min(y_sim[:,2]))-5,max(np.max(y_gmm[:,2]),np.max(y_sim[:,2]))+5)
title = ax.set_title("Recreated data")
plt.setp(title, color='black') 
plt.show()

# %% [markdown]
# The clusteres have been separated accurately!

# %% [markdown]
# ## GMM with diagonal clusters

# %%
N=5000
K=4
D=3
y_gmm = []
z_gmm = []
ind = []
mu = np.random.uniform(-30,30,size=(K,D))
# sigmas = [np.random.uniform(0,5, size=D) for i in range(K)]
# covariance = [np.diag(sigmas[k]) for k in range(K)]

sigmas = [np.random.normal(0,3, size=D) for i in range(K)]
covs = [np.diag(sigmas[k]) for k in range(K)]

while True:      # make sure to not have a negligible cluster
    theta = np.random.dirichlet(np.ones(K))
    if np.all(theta>(1.0/(2*K))):
        break
        
for i in range(N):
    opt = np.random.choice(list(range(K)),p=theta)
    z_gmm.append(opt)
    y_gmm.append(np.random.multivariate_normal(mu[opt],covs[opt]))
    ind.append(opt)
y_gmm = np.array(y_gmm)
ind = np.array(ind)
sns.set()

fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')
ax.scatter(y_gmm[:,0], y_gmm[:,1], y_gmm[:,2], c=z_gmm, cmap='viridis', alpha=0.3)
plt.show()

sample_theta = []
sample_sigma = []
sample_mu = []

for k in range(K):
    sample_theta.append(len(y_gmm[np.array(z_gmm)==k])/N)
    sample_mu.append(list(np.mean(y_gmm[np.array(z_gmm)==k], axis=0)))
    sample_sigma.append(np.std(y_gmm[np.array(z_gmm)==k].T,axis=1))

print('sample theta: ', sample_theta)
print()
for k in range(K):
    print('real mu_'+str(k)+': ', mu[k])
    print('sample mu_'+str(k)+': ', sample_mu[k])
    print('real sigmas_'+str(k)+':\n', sigmas[k])
    print('sample covariance_'+str(k)+':\n', sample_sigma[k])
    print()
# Out:
# /usr/lib/python3.7/site-packages/ipykernel_launcher.py:22: RuntimeWarning: covariance is not symmetric positive-semidefinite.
# sample theta:  [0.123, 0.357, 0.2262, 0.2938]
#
# real mu_0:  [  9.3793294   10.92156581 -26.51501513]
# sample mu_0:  [9.351071817611775, 10.895178060737436, -26.561078720970393]
# real sigmas_0:
#  [ 1.03430894 -0.24862294 -0.76387255]
# sample covariance_0:
#  [1.05613301 0.49004349 0.89310311]
#
# real mu_1:  [-21.56846688  18.06135487  29.89054755]
# sample mu_1:  [-21.513655211361012, 18.08749478054464, 29.851970547327664]
# real sigmas_1:
#  [-1.27260254 -2.35468605 -3.40299365]
# sample covariance_1:
#  [1.14491264 1.53581164 1.85440161]
#
# real mu_2:  [ 4.38608806  6.90638319 18.09625937]
# sample mu_2:  [4.356025935354016, 6.925912458173361, 18.10562001727612]
# real sigmas_2:
#  [-2.90671476 -1.20474161  6.3329397 ]
# sample covariance_2:
#  [1.73754845 1.08289373 2.519108  ]
#
# real mu_3:  [29.89246219  8.99646003 16.77395416]
# sample mu_3:  [29.823880546153347, 8.975915552030589, 16.801011991799992]
# real sigmas_3:
#  [-5.05226295 -0.71358413  1.86637387]
# sample covariance_3:
#  [2.15721835 0.84606084 1.39289146]

# %%
gmm_diag = loadStan('gmm_diag', recompile=True)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_4c78fbacd95d6f44e3e018d6bef5d11f NOW.
# Model compiled succesfully.
# Model saved succesfully to cache.

# %%
kmeans_init = KMeans(K).fit(y_gmm)

gmm_dat = {'N': N,'K': K, 'D':D, 'y':y_gmm}
fit = gmm_diag.sampling(data=gmm_dat, chains=1, iter=150, init=[{'mu':kmeans_init.cluster_centers_}])
fit_ext = fit.extract()
best_ind = np.where(fit_ext['lp__']==max(fit_ext['lp__']))[0][0]

z_sim = np.mean(fit_ext['z'],axis=0)
theta_sim = np.mean(fit_ext['theta'],axis=0)
mu_sim = np.mean(fit_ext['mu'],axis=0)
sigmas_sim = np.mean(fit_ext['sigma'],axis=0)

# %%
print('Real theta: ',theta)
print('Sample theta: ',sample_theta)
print('Simulated theta: ',theta_sim)
print()
print('Real mu:\n',mu)
print('Sample mu:\n',np.array(sample_mu))
print('Simulated mu:\n',mu_sim)
print()
print('Real sigmas:')
for i in range(K):
    print(sigmas[i])
print('Sample cov. matrices:\n',np.array(sample_sigma))
print('Simulated sigma:\n', sigmas_sim)
# Out:
# Real theta:  [0.12553173 0.3615508  0.22024467 0.2926728 ]
# Sample theta:  [0.123, 0.357, 0.2262, 0.2938]
# Simulated theta:  [0.2256838  0.35740742 0.1232646  0.29364418]
#
# Real mu:
#  [[  9.3793294   10.92156581 -26.51501513]
#  [-21.56846688  18.06135487  29.89054755]
#  [  4.38608806   6.90638319  18.09625937]
#  [ 29.89246219   8.99646003  16.77395416]]
# Sample mu:
#  [[  9.35107182  10.89517806 -26.56107872]
#  [-21.51365521  18.08749478  29.85197055]
#  [  4.35602594   6.92591246  18.10562002]
#  [ 29.82388055   8.97591555  16.80101199]]
# Simulated mu:
#  [[  4.34236346   6.92392849  18.10688661]
#  [-21.5114696   18.08609068  29.85214055]
#  [  9.35708901  10.89223009 -26.56799681]
#  [ 29.81853288   8.97923061  16.80190556]]
#
# Real sigmas:
# [ 1.03430894 -0.24862294 -0.76387255]
# [-1.27260254 -2.35468605 -3.40299365]
# [-2.90671476 -1.20474161  6.3329397 ]
# [-5.05226295 -0.71358413  1.86637387]
# Sample cov. matrices:
#  [[1.05613301 0.49004349 0.89310311]
#  [1.14491264 1.53581164 1.85440161]
#  [1.73754845 1.08289373 2.519108  ]
#  [2.15721835 0.84606084 1.39289146]]
# Simulated sigma:
#  [[3.03698725 1.1764582  6.3311175 ]
#  [1.31385307 2.36464013 3.4328073 ]
#  [1.12056098 0.24128316 0.8054905 ]
#  [4.68440329 0.71784809 1.94506199]]

# %%
z_sim_norm = (np.exp(z_sim).T/sum(np.exp(z_sim).T)).T

z_cats = np.argmax(z_sim_norm, axis=1)

z_sim_rec, y_sim = [], []
for i in range(N):
    opt = np.random.choice(list(range(K)),p=theta_sim)
    z_sim_rec.append(opt)
    y_sim.append(np.random.multivariate_normal(mu_sim[opt],np.diag(sigmas_sim[opt])))

y_sim = np.array(y_sim)    
    
fig = plt.figure(figsize=(15,10))

ax = fig.add_subplot(2,2,1, projection='3d')
ax.scatter(np.array(y_gmm)[:,0], np.array(y_gmm)[:,1], np.array(y_gmm)[:,2], c=z_gmm, cmap='viridis', alpha=0.6)
ax.set_xlim(min(np.min(y_gmm[:,0]),np.min(y_sim[:,0]))-5,max(np.max(y_gmm[:,0]),np.max(y_sim[:,0]))+5)
ax.set_ylim(min(np.min(y_gmm[:,1]),np.min(y_sim[:,1]))-5,max(np.max(y_gmm[:,1]),np.max(y_sim[:,1]))+5)
ax.set_zlim(min(np.min(y_gmm[:,2]),np.min(y_sim[:,2]))-5,max(np.max(y_gmm[:,2]),np.max(y_sim[:,2]))+5)
title = ax.set_title("Original sample")
plt.setp(title, color='black') 

ax = fig.add_subplot(2,2,2, projection='3d')
ax.scatter(np.array(y_gmm)[:,0], np.array(y_gmm)[:,1], np.array(y_gmm)[:,2], cmap='viridis')
ax.set_xlim(min(np.min(y_gmm[:,0]),np.min(y_sim[:,0]))-5,max(np.max(y_gmm[:,0]),np.max(y_sim[:,0]))+5)
ax.set_ylim(min(np.min(y_gmm[:,1]),np.min(y_sim[:,1]))-5,max(np.max(y_gmm[:,1]),np.max(y_sim[:,1]))+5)
ax.set_zlim(min(np.min(y_gmm[:,2]),np.min(y_sim[:,2]))-5,max(np.max(y_gmm[:,2]),np.max(y_sim[:,2]))+5)
title = ax.set_title("Unlabeled sample")
plt.setp(title, color='black') 

ax = fig.add_subplot(2,2,3, projection='3d')
ax.scatter(np.array(y_gmm)[:,0], np.array(y_gmm)[:,1], np.array(y_gmm)[:,2], c=z_cats, cmap='viridis', alpha=0.6)
ax.scatter(mu_sim[:,0], mu_sim[:,1], mu_sim[:,2], c='red')
ax.set_xlim(min(np.min(y_gmm[:,0]),np.min(y_sim[:,0]))-5,max(np.max(y_gmm[:,0]),np.max(y_sim[:,0]))+5)
ax.set_ylim(min(np.min(y_gmm[:,1]),np.min(y_sim[:,1]))-5,max(np.max(y_gmm[:,1]),np.max(y_sim[:,1]))+5)
ax.set_zlim(min(np.min(y_gmm[:,2]),np.min(y_sim[:,2]))-5,max(np.max(y_gmm[:,2]),np.max(y_sim[:,2]))+5)
title = ax.set_title("Guessed clusters")
plt.setp(title, color='black') 

ax = fig.add_subplot(2,2,4, projection='3d')
ax.scatter(np.array(y_sim)[:,0], np.array(y_sim)[:,1], np.array(y_sim)[:,2], c=z_sim_rec, cmap='viridis', alpha=0.6)
ax.set_xlim(min(np.min(y_gmm[:,0]),np.min(y_sim[:,0]))-5,max(np.max(y_gmm[:,0]),np.max(y_sim[:,0]))+5)
ax.set_ylim(min(np.min(y_gmm[:,1]),np.min(y_sim[:,1]))-5,max(np.max(y_gmm[:,1]),np.max(y_sim[:,1]))+5)
ax.set_zlim(min(np.min(y_gmm[:,2]),np.min(y_sim[:,2]))-5,max(np.max(y_gmm[:,2]),np.max(y_sim[:,2]))+5)
title = ax.set_title("Recreated data")
plt.setp(title, color='black') 
plt.show()
