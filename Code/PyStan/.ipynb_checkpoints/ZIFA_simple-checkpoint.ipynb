# %% [markdown]
# # ZIFA in PyStan (simple)
#
# In this notebook, we try to perform a zero-inflated factor analysis (ZIFA) in Pystan. Unlike the 'ZIFA' notebook, we try to only express the model and not the complete log-likelihood.

# %%
from mpl_toolkits.mplot3d import Axes3D
import pystan
import numpy as np
import seaborn as sns
sns.set()

import os
os.sys.path.append('../Python')
import ZIFA

# %% [markdown]
# Here, the model is defined in Stan. It is based on the original model as defined by Pierson (2015). Note that we make use of the logit-transformed bernoulli parametrization as it is numerically more stable on the given scale.

# %%
zifa_simple = """

data{
    int<lower=0> N; // number  of  datapoints
    int<lower=0> D; // number  of  dimensions  in  observed  dataset
    int<lower=0> M; // number  of  dimensions  in  latent  dataset
    matrix[N,D] y; // zero inflated observations
}

transformed data{
    int h[N,D]; // zero-inflation
    
    for (n in 1:N){
        for (d in 1:D){
            if (y[n,d] == 0.0){
                h[n,d] = 1;
            } else {
                h[n,d] = 0;
            }
        }
    }
}

parameters{
    matrix[M,N] z;  // latent data
    matrix[D,M] A;  // factor loadings
    vector<lower=0>[D] sigmas;   //  standard  deviations
    real<lower=0, upper=0.5> lambda; // zero-inflation
    vector[D] mu;   //  added means
    matrix<lower=0>[N,D] x; // non-inflated observations
}

transformed parameters{
    // means and covariacne matrix of z
    vector[M] mean_z;
    matrix[M,M] cov_z;
    
    for (m in 1:M){
        mean_z[m] = 0.0;
        for (n in 1:M){
            if (m==n){
                cov_z[m,n]=1.0;
            } else{
                cov_z[m,n]=0.0;
            }
        }
    }
}

model{
    
    matrix[D,D] W;
    for (i in 1:D){
        for (j in 1:D){
            if (i==j){
                W[i,j] = sigmas[i];
            } else {
                W[i,j] = 0.0;
            }
        }
    }
    
    for (n in 1:N){
        z[:,n] ~ multi_normal(mean_z, cov_z);
        x[n,:] ~ multi_normal(A*z[:,n]+mu,W);
        for (d in 1:D){
            h[n,d] ~ bernoulli(exp(-lambda*square(x[n,d])));
            if (y[n,d] != 0.0){
                y[n,d] ~ normal(row(A,d)*col(z,n)+mu[d], sigmas[d]);
                } else {
                //x[n,d] ~ normal(row(A,d)*col(z,n)+mu[d], sigmas[d]);
                }
        }
    }
}

"""
zifa_model_simple = pystan.StanModel(model_code=zifa_simple)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_c5ac65810e8b9c7842ae8300ece580cb NOW.

# %% [markdown]
# Note the log-probability in the 'model'-section of the code. We take $p(\sigma^2)$, $p(z)$ and $p(x|z)$ into account first. Then we take $p(h=1|x)$ or $p(h=0|x)$, depending on whether the datapoint is zero or non-zero. The reasoning behind this is given in the supplementary material of E. Pierson (2015). Unlike the original article, we also take $p(y|z,h)$ (which is $1$ is $h=1$) into account, to get a more accurate estimate of $z$, $A$ and $W$. We end up with a complete likelihood of $$\prod^N_{i=1}p(z_i)\Big(\prod_{j:y_{i,j}=0}p(x_{i,j}|z_i)p(h_{i,j}=1|x_{i,j})\prod_{j:y_{i,j}\neq}p(x_{i,j}|z_i)p(h_{i,j}=0|x_{i,j})\Big)$$
#
# Note that our model does not take the prior distributions of $\mu$, $\sigma^2$ and $W$ into account, like the original model. This is because these parameters were chosen manually or came from uniform distributions in the original paper, leaving them with flat priors.

# %% [markdown]
# We specify our parameters as done in the original paper and generate some data.

# %%
N=150
D=3
M=2

z = np.random.multivariate_normal(np.zeros(M),cov=np.eye(M), size=(N)).T
mu = np.random.uniform(2.7,3.3,size=(D,1))
lamda = 0.1
sigma_A = 0.3
A = np.zeros((D,M))

for i in range(D):
    for j in range(M):
        if i==j:
            A[i,j] = np.random.uniform(.9*sigma_A,1.1*sigma_A)
        else:
            A[i,j] = np.random.uniform(-.5,.5)

            
W = np.random.uniform(2.7,3.3,size=(D,1))
x = np.random.normal(np.matmul(A,z)+mu,W).T
h = np.random.binomial(n=1, p=1-np.exp(-(x**2)*lamda))
y = x*h
y[y<0] = 0

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(y[:,0],y[:,1],y[:,2], label='Observed data', alpha=0.6)
title = ax.set_title("Simulated data")
plt.setp(title, color='black') 
ax.set_xlabel('Gene 1')
ax.set_ylabel('Gene 2')
ax.set_zlabel('Gene 3')
plt.show()

plt.hist(y[:,0], alpha=0.4, label='Gene 1')
plt.hist(y[:,1], alpha=0.4, label='Gene 2')
plt.hist(y[:,2], alpha=0.4, label='Gene 3')
plt.legend()
plt.show()

# %% [markdown]
# Note that $x$ and $y_{y\not=0}$ are assumed to come from the same distribution in the model and this assumption is used to estimate $x$, which is again used to estimate $\lambda$, but this assumption does not hold! since the lowest values of $x$ were put to $0$, $y_{y\not=0}$ has a higher mean and lower standard deviation! This is hwy the model tends to be inaccurate when estimating $x$, and as a result, $\lambda$ is estimated too low. The effect is especially strong when $y$ has positive values, as is the case in gene-expression data. The original paper describing ZIFA makes note of this, and they do separate $y$ into $y_{y\not=0}$ and $y_{y=0}$ when formulating their EM-algorithm, but I have not found a way to incorporate this into the PyStan module as of yet.
#
# Edit: The code is slightly altered to represent the model more than the log-likelihood as given by Pierson (the distribution over the whole of $x$ is specified instead of only on $x_{i,j}|y_{i,j}\not=0$). Due to this alteration, $x$ is now estimated to low and $\lambda$ too high, but it is unclear why this happens.

# %%
y_nz_mean, y_nz_std = [], []
sns.set()
fig = plt.figure(figsize=(4*D,3))
for i in range(D):
    ax = fig.add_subplot(1,3,i+1)
    y_tmp = y[:,i][y[:,i]!=0]
    ax.hist(y_tmp, bins=int(N/3), alpha=1, label='y_nonzero')
    ax.hist(np.concatenate(x), bins=int(N/3), alpha=0.5, label='x')
    ax.legend()
    ax.set_title('Gene '+str(i+1))
    y_nz_mean.append(np.mean(y_tmp))
    y_nz_std.append(np.std(y_tmp))
plt.show()
print('mean of x: ', np.mean(x, axis=0), ', std. dev. of x: ', np.std(x, axis=0))

print('mean of non-zero y: ', y_nz_mean, ', std. dev. of non-zero y: ', y_nz_std)
# Out:
# mean of x:  [2.94540186 3.0345023  2.91242263] , std. dev. of x:  [2.96048613 3.15637734 2.74281362]
# mean of non-zero y:  [5.015716061793573, 5.075010283390075, 4.7667733288898555] , std. dev. of non-zero y:  [1.962234731305297, 2.255094193715718, 2.038563887608598]

# %% [markdown]
# And then we can optimize our parameters and latent dataset.

# %%
zifa_dat = {'N': N, 'D':D, 'M':M, 'y':y}
fit = zifa_model_simple.sampling(data=zifa_dat, chains=1, iter=200)
fit_ext = fit.extract()
best_ind = np.where(fit_ext['lp__']==max(fit_ext['lp__']))[0][0]
# Out:
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed

# %%
z_sim = fit_ext['z'][best_ind]
mu_sim = np.mean(fit_ext['mu'],axis=0)
W_sim = np.mean(fit_ext['sigmas'],axis=0)
lambda_sim = np.mean(fit_ext['lambda'],axis=0)
A_sim = np.mean(fit_ext['A'],axis=0)

# x_sim = fit_ext['x'][best_ind]    # x can be taken from the samples
x_sim = np.random.normal(np.matmul(z_sim.T,A_sim.T)+mu_sim,W_sim)    # or x can be recreated from z, W and sigma
h_sim = np.random.binomial(n=1, p=1-np.exp(-(x_sim**2)*lambda_sim))
y_sim = x_sim*h_sim

print('real mu: ', mu.T)
print('simulated mu: ', mu_sim)
print()
print('real W: ', W[:,0])
print('simulated W: ', W_sim)
print()
print('real lambda: ', lamda)
print('simulated lambda: ', lambda_sim)
print()
print('real AA^T:\n', np.matmul(A,A.T))
print('simulated AA^T:\n', np.matmul(A_sim,A_sim.T))
print()
# Out:
# real mu:  [[3.08220104 2.91985859 2.89298624]]
# simulated mu:  [4.84477208 4.97702863 4.6995198 ]
#
# real W:  [2.84771425 3.27880829 2.80484789]
# simulated W:  [1.74881628 2.10337078 1.98180742]
#
# real lambda:  0.1
# simulated lambda:  0.03416106090556775
#
# real AA^T:
#  [[ 0.12568826  0.0835574  -0.03884674]
#  [ 0.0835574   0.32223549  0.01363699]
#  [-0.03884674  0.01363699  0.01784577]]
# simulated AA^T:
#  [[ 0.44797308 -0.33967957 -0.04167735]
#  [-0.33967957  0.27684022  0.06054003]
#  [-0.04167735  0.06054003  0.04732179]]

# %%
print('Real mean of x: ',np.mean(x, axis=0))
print('Simulated mean of x: ',np.mean(x_sim, axis=0))
print('mean of non-zero y: ', y_nz_mean)
print()
print('Real cov. matrix of x:\n',np.cov(x.T))
print('Simulated cov. matrix of x:\n',np.cov(x_sim.T))
print()
print('Real mean of z: ',np.mean(z, axis=1))
print('Simulated mean of z: ',np.mean(z_sim, axis=1))
print()
print('Real cov. matrix of z:\n',np.cov(z))
print('Simulated cov. matrix of z:\n',np.cov(z_sim))
# Out:
# Real mean of x:  [2.94540186 3.0345023  2.91242263]
# Simulated mean of x:  [4.68299704 5.02035835 4.73325256]
# mean of non-zero y:  [5.015716061793573, 5.075010283390075, 4.7667733288898555]
#
# Real cov. matrix of x:
#  [[ 8.82330013 -0.02682473  0.09824964]
#  [-0.02682473 10.02958182 -0.95147025]
#  [ 0.09824964 -0.95147025  7.57351665]]
# Simulated cov. matrix of x:
#  [[ 3.37747678 -0.3422695  -0.08670138]
#  [-0.3422695   4.91528943 -0.52804043]
#  [-0.08670138 -0.52804043  4.17313581]]
#
# Real mean of z:  [-0.11026461 -0.13216266]
# Simulated mean of z:  [-0.12702745 -0.03958688]
#
# Real cov. matrix of z:
#  [[1.04808065 0.0635891 ]
#  [0.0635891  1.18744967]]
# Simulated cov. matrix of z:
#  [[ 0.86687107 -0.03533091]
#  [-0.03533091  1.00170156]]

# %% [markdown]
# The result is plotted below. The result looks a lot like the original. However, $\bar{A}$ is still not a correct rotation of $A$ and $\bar{x}$ has a different mean (although $\mu$ tends to be guessed correctly!) and covariance matrix, but the differences between $\bar{x}$ and $x$ are relatively small.

# %%
sns.set()
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(1,2,1, projection='3d')
ax.scatter(y[:,0],y[:,1],y[:,2], label='Observed data', alpha=0.5)
title = ax.set_title("Zero-inflated data - original")
plt.setp(title, color='black') 
ax.set_xlabel('Gene 1')
ax.set_ylabel('Gene 2')
ax.set_zlabel('Gene 3')
ax = fig.add_subplot(1,2,2, projection='3d')
ax.scatter(y_sim[:,0],y_sim[:,1],y_sim[:,2], label='Simulated data', alpha=0.5)
title = ax.set_title("Zero-inflated data - simulation")
plt.setp(title, color='black') 
ax.set_xlabel('Gene 1')
ax.set_ylabel('Gene 2')
ax.set_zlabel('Gene 3')
plt.show()

fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(1,2,1)
ax.hist(y[:,0], alpha=0.6)
ax.hist(y[:,1], alpha=0.6)
ax.hist(y[:,2], alpha=0.6)
ax.set_xlim(min(np.min(y),np.min(y_sim)),max(np.max(y),np.max(y_sim)))
ax.set_ylim((0,N))
title = ax.set_title("Zero-inflated data - simulation")
plt.setp(title, color='black') 
ax = fig.add_subplot(1,2,2)
ax.hist(y_sim[:,0], alpha=0.6)
ax.hist(y_sim[:,1], alpha=0.6)
ax.hist(y_sim[:,2], alpha=0.6)
ax.set_ylim((0,N))
ax.set_xlim(min(np.min(y),np.min(y_sim)),max(np.max(y),np.max(y_sim)))
title = ax.set_title("Zero-inflated data - simulation")
plt.setp(title, color='black') 
plt.show()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x[:,0],x[:,1],x[:,2], label='Observed data', alpha=0.3)
ax.scatter(x_sim[:,0],x_sim[:,1],x_sim[:,2], label='Simulated data', alpha=0.3)
title = ax.set_title("Data without zero-inflation")
plt.setp(title, color='black') 
ax.set_xlabel('Gene 1')
ax.set_ylabel('Gene 2')
ax.set_zlabel('Gene 3')
plt.legend()
plt.show()

fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(1,2,1)
ax.hist(x[:,0], alpha=0.6)
ax.hist(x[:,1], alpha=0.6)
ax.hist(x[:,2], alpha=0.6)
ax.set_xlim(min(np.min(x),np.min(x_sim)),max(np.max(x),np.max(x_sim)))
ax.set_ylim((0,N/2))
title = ax.set_title("Data without zero-inflation - simulation")
plt.setp(title, color='black') 
ax = fig.add_subplot(1,2,2)
ax.hist(x_sim[:,0], alpha=0.6)
ax.hist(x_sim[:,1], alpha=0.6)
ax.hist(x_sim[:,2], alpha=0.6)
ax.set_xlim(min(np.min(x),np.min(x_sim)),max(np.max(x),np.max(x_sim)))
ax.set_ylim((0,N/2))
title = ax.set_title("Data without zero-inflation - simulation")
plt.setp(title, color='black') 
plt.show()

plt.scatter(z[0,:], z[1,:], label='real latent data', alpha=0.4)
plt.scatter(z_sim[0,:], z_sim[1,:], label='simulated latent data', alpha=0.4)
plt.legend()
plt.show()

# %% [markdown]
# ### ZIFA as implemented by Pierson
# Let's compare our findings with the [implentation of ZIFA as done by Pierson](https://github.com/epierson9/ZIFA).

# %%
Zhat, params = ZIFA.fitModel(y, M)

plt.figure(figsize=[17, 4])
plt.subplot(131)
plt.scatter(z[0,:], z[1,:])
plt.title('True Latent Positions\nFraction of Zeros %2.3f' % (y == 0).mean())
plt.xlim([-4, 4])
plt.ylim([-4, 4])
plt.subplot(132)
plt.scatter(Zhat[:,0], Zhat[:,1])
plt.xlim([-4, 4])
plt.ylim([-4, 4])
plt.title('ZIFA Estimated Latent Positions')
plt.subplot(133)
plt.scatter(z_sim[0,:], z_sim[1,:])
plt.xlim([-4, 4])
plt.ylim([-4, 4])
plt.title('Pystan Estimated Latent Positions')
plt.show()

noise = np.zeros([D, N])
for j in range(D):
    noise[j, :] = params['mus'][j] + np.random.normal(loc=0, scale=params['sigmas'][j], size=N)
Xhat = np.matmul(params['A'],Zhat.T)+noise

fig = plt.figure(figsize=(17,4))
ax = fig.add_subplot(1,3,1)
ax.hist(x[:,0], alpha=0.6)
ax.hist(x[:,1], alpha=0.6)
ax.hist(x[:,2], alpha=0.6)
ax.set_xlim(min([np.min(x),np.min(Xhat),np.min(x_sim)]),max([np.max(x),np.max(Xhat),np.max(x_sim)]))
ax.set_ylim((0,N/2))
title = ax.set_title("Actual data without zero-inflation")
plt.setp(title, color='black') 
ax = fig.add_subplot(1,3,2)
ax.hist(Xhat[0,:], alpha=0.6)
ax.hist(Xhat[1,:], alpha=0.6)
ax.hist(Xhat[2,:], alpha=0.6)
ax.set_xlim(min([np.min(x),np.min(Xhat),np.min(x_sim)]),max([np.max(x),np.max(Xhat),np.max(x_sim)]))
ax.set_ylim((0,N/2))
title = ax.set_title("Data without zero-inflation - Pierson")
plt.setp(title, color='black') 
ax = fig.add_subplot(1,3,3)
ax.hist(x_sim[:,0], alpha=0.6)
ax.hist(x_sim[:,1], alpha=0.6)
ax.hist(x_sim[:,2], alpha=0.6)
ax.set_xlim(min([np.min(x),np.min(Xhat),np.min(x_sim)]),max([np.max(x),np.max(Xhat),np.max(x_sim)]))
ax.set_ylim((0,N/2))
title = ax.set_title("Data without zero-inflation - PyStan")
plt.setp(title, color='black') 
plt.show()

Hhat = np.random.binomial(n=1, p=1-np.exp(-(Xhat**2)*params['decay_coef']))
Yhat = Xhat*Hhat
Yhat[Yhat<0] = 0

fig = plt.figure(figsize=(17,4))
ax = fig.add_subplot(1,3,1)
ax.hist(y[:,0], alpha=0.6)
ax.hist(y[:,1], alpha=0.6)
ax.hist(y[:,2], alpha=0.6)
ax.set_xlim(min([np.min(y),np.min(Yhat),np.min(y_sim)]),max([np.max(y),np.max(Yhat),np.max(y_sim)]))
ax.set_ylim((0,np.max([sum(y==0),sum(y_sim==0),sum(Yhat.T==0)])*1.05))
title = ax.set_title("Zero-inflated data - simulation")
plt.setp(title, color='black') 
ax = fig.add_subplot(1,3,2)
ax.hist(Yhat[0,:], alpha=0.6)
ax.hist(Yhat[1,:], alpha=0.6)
ax.hist(Yhat[2,:], alpha=0.6)
ax.set_ylim((0,np.max([sum(y==0),sum(y_sim==0),sum(Yhat.T==0)])*1.05))
ax.set_xlim(min([np.min(y),np.min(Yhat),np.min(y_sim)]),max([np.max(y),np.max(Yhat),np.max(y_sim)]))
title = ax.set_title("Zero-inflated data - ZIFA")
plt.setp(title, color='black') 
ax = fig.add_subplot(1,3,3)
ax.hist(y_sim[:,0], alpha=0.6)
ax.hist(y_sim[:,1], alpha=0.6)
ax.hist(y_sim[:,2], alpha=0.6)
ax.set_ylim((0,np.max([sum(y==0),sum(y_sim==0),sum(Yhat.T==0)])*1.05))
ax.set_xlim(min([np.min(y),np.min(Yhat),np.min(y_sim)]),max([np.max(y),np.max(Yhat),np.max(y_sim)]))
title = ax.set_title("Zero-inflated data - PyStan")
plt.setp(title, color='black') 
plt.show()
# Out:
# Running zero-inflated factor analysis with N = 150, D = 3, K = 2
# Param change below threshold 1.000e-02 after 6 iterations

# %%
print('real AA^T:\n', np.matmul(A,A.T))
print('PyStan AA^T:\n', np.matmul(A_sim,A_sim.T))
print('ZIFA AA^T:\n',np.matmul(params['A'],params['A'].T))
print()
print('real mu: ', mu.T)
print('PyStan mu: ', mu_sim)
print('ZIFA mu: ',params['mus'].T[0])
print()
print('real W: ', W[:,0])
print('PyStan W: ', W_sim)
print('ZIFA W: ',params['sigmas'].T[0])
print()
print('real lambda: ', lamda)
print('PyStan lambda: ', lambda_sim)
print('ZIFA lambda: ',params['decay_coef'])
print()
print('Real mean of x: ',np.mean(x, axis=0))
print('PyStan mean of x: ',np.mean(x_sim, axis=0))
print('ZIFA mean of x: ',np.mean(np.matmul(params['A'],Zhat.T)+params['mus'][j], axis=1))
# Out:
# real AA^T:
#  [[ 0.12568826  0.0835574  -0.03884674]
#  [ 0.0835574   0.32223549  0.01363699]
#  [-0.03884674  0.01363699  0.01784577]]
# PyStan AA^T:
#  [[ 0.44797308 -0.33967957 -0.04167735]
#  [-0.33967957  0.27684022  0.06054003]
#  [-0.04167735  0.06054003  0.04732179]]
# ZIFA AA^T:
#  [[ 5.00305473 -0.46716637 -0.47648699]
#  [-0.46716637  6.24452589 -0.37624544]
#  [-0.47648699 -0.37624544  0.07392777]]
#
# real mu:  [[3.08220104 2.91985859 2.89298624]]
# PyStan mu:  [4.84477208 4.97702863 4.6995198 ]
# ZIFA mu:  [3.30854545 3.27475541 3.35298562]
#
# real W:  [2.84771425 3.27880829 2.80484789]
# PyStan W:  [1.74881628 2.10337078 1.98180742]
# ZIFA W:  [1.28401319 1.25239014 2.42110185]
#
# real lambda:  0.1
# PyStan lambda:  0.03416106090556775
# ZIFA lambda:  0.07740252237876337
#
# Real mean of x:  [2.94540186 3.0345023  2.91242263]
# PyStan mean of x:  [4.68299704 5.02035835 4.73325256]
# ZIFA mean of x:  [3.44591461 3.46833025 3.33572012]

# %% [markdown]
# ## ZI-PPCA

# %%
zippca_simple = """

data{
    int<lower=0> N; // number  of  datapoints
    int<lower=0> D; // number  of  dimensions  in  observed  dataset
    int<lower=0> M; // number  of  dimensions  in  latent  dataset
    matrix[N,D] y; // zero inflated observations
}

transformed data{
    int h[N,D]; // zero-inflation
    
    for (n in 1:N){
        for (d in 1:D){
            if (y[n,d] == 0.0){
                h[n,d] = 1;
            } else {
                h[n,d] = 0;
            }
        }
    }
}

parameters{
    matrix[M,N] z;  // latent data
    matrix[D,M] A;  // factor loadings
    real<lower=0> sigma;   //  standard  deviations
    real<lower=0, upper=0.5> lambda; // zero-inflation
    vector[D] mu;   //  added means
    matrix[N,D] x; // non-inflated observations
}

transformed parameters{
    // means and covariacne matrix of z
    vector[M] mean_z;
    matrix[M,M] cov_z;
    
    for (m in 1:M){
        mean_z[m] = 0.0;
        for (n in 1:M){
            if (m==n){
                cov_z[m,n]=1.0;
            } else{
                cov_z[m,n]=0.0;
            }
        }
    }
}

model{
    
    matrix[D,D] W;
    for (i in 1:D){
        for (j in 1:D){
            if (i==j){
                W[i,j] = sigma;
            } else {
                W[i,j] = 0.0;
            }
        }
    }
    
    for (n in 1:N){
        z[:,n] ~ multi_normal(mean_z, cov_z);
        x[n,:] ~ multi_normal(A*z[:,n]+mu,W);
        for (d in 1:D){
            h[n,d] ~ bernoulli(exp(-lambda*square(x[n,d])));
            if (y[n,d] != 0.0){
                y[n,d] ~ normal(row(A,d)*col(z,n)+mu[d], sigma);
                } else {
                //x[n,d] ~ normal(row(A,d)*col(z,n)+mu[d], sigma);
                }
        }
    }
}

"""

zippca_model_simple = pystan.StanModel(model_code=zippca_simple)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_d426f2d2ca1ed0fd8477ce38071ef430 NOW.

# %%
N=150
D=3
M=2

z = np.random.normal(0,1, size=(M,N))
mu = np.random.uniform(2.7,3.3,size=(D,1))
lamda = 0.1
sigma_A = 0.3
A = np.zeros((D,M))

for i in range(D):
    for j in range(M):
        if i==j:
            A[i,j] = np.random.uniform(.9*sigma_A,1.1*sigma_A)
        else:
            A[i,j] = np.random.uniform(-.5,.5)

            
sigma = np.random.uniform(2.7,3.3)
x = np.random.normal(np.matmul(A,z)+mu,sigma).T
h = np.random.binomial(n=1, p=1-np.exp(-(x**2)*lamda))
y = x*h

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(y[:,0],y[:,1],y[:,2], label='Observed data', alpha=0.6)
title = ax.set_title("Simulated data")
plt.setp(title, color='black') 
ax.set_xlabel('Gene 1')
ax.set_ylabel('Gene 2')
ax.set_zlabel('Gene 3')
plt.show()

plt.hist(y[:,0], alpha=0.4, label='Gene 1')
plt.hist(y[:,1], alpha=0.4, label='Gene 2')
plt.hist(y[:,2], alpha=0.4, label='Gene 3')
plt.legend()
plt.show()

# %% [markdown]
# And then we can optimize our parameters and latent dataset.

# %%
zippca_dat = {'N': N, 'D':D, 'M':M, 'y':y}
fit = zippca_model_simple.sampling(data=zippca_dat, chains=1, iter=200, verbose=True)
fit_ext = fit.extract()
best_ind = np.where(fit_ext['lp__']==max(fit_ext['lp__']))[0][0]
# Out:
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed

# %%
z_sim = fit_ext['z'][best_ind]
mu_sim = np.mean(fit_ext['mu'],axis=0)
sigma_sim = np.mean(fit_ext['sigma'],axis=0)
lambda_sim = np.mean(fit_ext['lambda'],axis=0)
A_sim = np.mean(fit_ext['A'],axis=0)

x_sim = fit_ext['x'][best_ind]
# x_sim = np.random.normal(np.matmul(z_sim.T,A_sim.T)+mu_sim,sigma_sim)    # or x can be recreated from z, W and sigma
h_sim = np.random.binomial(n=1, p=1-np.exp(-(x_sim**2)*lambda_sim))
y_sim = x_sim*h_sim

print('real mu: ', mu.T)
print('simulated mu: ', mu_sim)
print()
print('real sigma: ', sigma)
print('simulated sigma: ', sigma_sim)
print()
print('real lambda: ', lamda)
print('simulated lambda: ', lambda_sim)
print()
print('real AA^T:\n', np.matmul(A,A.T))
print('simulated AA^T:\n', np.matmul(A_sim,A_sim.T))
print()
# Out:
# real mu:  [[2.71390185 2.71140105 2.9411747 ]]
# simulated mu:  [0.71604544 0.76958773 0.81289688]
#
# real sigma:  2.984576204587195
# simulated sigma:  4.514321601238476
#
# real lambda:  0.1
# simulated lambda:  0.2848358096301758
#
# real AA^T:
#  [[ 0.14766431 -0.06519566 -0.04026402]
#  [-0.06519566  0.08956098 -0.03224857]
#  [-0.04026402 -0.03224857  0.05215557]]
# simulated AA^T:
#  [[ 0.44839331  0.37010401 -0.48330203]
#  [ 0.37010401  0.4039866  -0.30169667]
#  [-0.48330203 -0.30169667  0.61688456]]

# %%
print('Real mean of x: ',np.mean(x, axis=0))
print('Simulated mean of x: ',np.mean(x_sim, axis=0))
print()
print('Real cov. matrix of x:\n',np.cov(x.T))
print('Simulated cov. matrix of x:\n',np.cov(x_sim.T))
print()
print('Real mean of z: ',np.mean(z, axis=1))
print('Simulated mean of z: ',np.mean(z_sim, axis=1))
print()
print('Real cov. matrix of z:\n',np.cov(z))
print('Simulated cov. matrix of z:\n',np.cov(z_sim))
# Out:
# Real mean of x:  [2.52180795 2.21302948 3.01162828]
# Simulated mean of x:  [0.33378804 0.27465511 0.40497779]
#
# Real cov. matrix of x:
#  [[7.77843037 0.63048112 0.49579339]
#  [0.63048112 8.52857433 0.25903103]
#  [0.49579339 0.25903103 7.31687406]]
# Simulated cov. matrix of x:
#  [[ 3.947034    0.3616217  -0.59589433]
#  [ 0.3616217   5.21292804 -0.74833909]
#  [-0.59589433 -0.74833909  4.88954113]]
#
# Real mean of z:  [ 0.02571617 -0.04535   ]
# Simulated mean of z:  [-0.10718297  0.05759434]
#
# Real cov. matrix of z:
#  [[ 1.04566578 -0.02239163]
#  [-0.02239163  0.80669641]]
# Simulated cov. matrix of z:
#  [[ 0.86226234 -0.02575219]
#  [-0.02575219  0.97625296]]

# %%
sns.set()
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(1,2,1, projection='3d')
ax.scatter(y[:,0],y[:,1],y[:,2], label='Observed data', alpha=0.5)
title = ax.set_title("Zero-inflated data - original")
plt.setp(title, color='black') 
ax.set_xlabel('Gene 1')
ax.set_ylabel('Gene 2')
ax.set_zlabel('Gene 3')
ax = fig.add_subplot(1,2,2, projection='3d')
ax.scatter(y_sim[:,0],y_sim[:,1],y_sim[:,2], label='Simulated data', alpha=0.5)
title = ax.set_title("Zero-inflated data - simulation")
plt.setp(title, color='black') 
ax.set_xlabel('Gene 1')
ax.set_ylabel('Gene 2')
ax.set_zlabel('Gene 3')
plt.show()

fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(1,2,1)
ax.hist(y[:,0], alpha=0.6)
ax.hist(y[:,1], alpha=0.6)
ax.hist(y[:,2], alpha=0.6)
ax.set_xlim(min(np.min(y),np.min(y_sim)),max(np.max(y),np.max(y_sim)))
ax.set_ylim((0,N))
title = ax.set_title("Zero-inflated data - simulation")
plt.setp(title, color='black') 
ax = fig.add_subplot(1,2,2)
ax.hist(y_sim[:,0], alpha=0.6)
ax.hist(y_sim[:,1], alpha=0.6)
ax.hist(y_sim[:,2], alpha=0.6)
ax.set_ylim((0,N))
ax.set_xlim(min(np.min(y),np.min(y_sim)),max(np.max(y),np.max(y_sim)))
title = ax.set_title("Zero-inflated data - simulation")
plt.setp(title, color='black') 
plt.show()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x[:,0],x[:,1],x[:,2], label='Observed data', alpha=0.3)
ax.scatter(x_sim[:,0],x_sim[:,1],x_sim[:,2], label='Simulated data', alpha=0.3)
title = ax.set_title("Data without zero-inflation")
plt.setp(title, color='black') 
ax.set_xlabel('Gene 1')
ax.set_ylabel('Gene 2')
ax.set_zlabel('Gene 3')
plt.legend()
plt.show()

fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(1,2,1)
ax.hist(x[:,0], alpha=0.6)
ax.hist(x[:,1], alpha=0.6)
ax.hist(x[:,2], alpha=0.6)
ax.set_xlim(min(np.min(x),np.min(x_sim)),max(np.max(x),np.max(x_sim)))
ax.set_ylim((0,N/2))
title = ax.set_title("Data without zero-inflation - simulation")
plt.setp(title, color='black') 
ax = fig.add_subplot(1,2,2)
ax.hist(x_sim[:,0], alpha=0.6)
ax.hist(x_sim[:,1], alpha=0.6)
ax.hist(x_sim[:,2], alpha=0.6)
ax.set_xlim(min(np.min(x),np.min(x_sim)),max(np.max(x),np.max(x_sim)))
ax.set_ylim((0,N/2))
title = ax.set_title("Data without zero-inflation - simulation")
plt.setp(title, color='black') 
plt.show()

plt.scatter(z[0,:], z[1,:], label='real latent data', alpha=0.4)
plt.scatter(z_sim[0,:], z_sim[1,:], label='simulated latent data', alpha=0.4)
plt.legend()
plt.show()
